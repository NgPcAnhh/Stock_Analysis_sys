# %%
from pathlib import Path
import json
import ast
import re
import requests
import pandas as pd
from IPython.display import display

# %%
ROOT = Path.cwd()

META_PATH = ROOT / "knowledge" / "metadata.md"
BCTC_PATH = ROOT / "knowledge" / "bctc_description.md"

EMBED_URL = "http://localhost:1234/v1/embeddings"
EMBED_MODEL = "BAAI/bge-m3"

# số object mỗi chunk (tuning ở đây)
BCTC_CHUNK_SIZE = 1

# %%
metadata_text = META_PATH.read_text(encoding="utf-8")
bctc_raw_text = BCTC_PATH.read_text(encoding="utf-8")

print("Loaded OK")
# Out:
# Loaded OK

# %%
def count_tokens(text):
    return len(tokenizer.encode(text))

# %% [markdown]
# chunking metadata.md

# %%
def split_metadata_by_table(text):
    chunks = []
    current = []

    for line in text.splitlines():
        if line.startswith("## ") and "Bảng " in line:
            if current:
                chunks.append("\n".join(current).strip())
                current = []
        current.append(line)

    if current:
        chunks.append("\n".join(current).strip())

    return chunks


metadata_chunks = split_metadata_by_table(metadata_text)

# %%
def inspect_chunks(chunks, name):
    rows = []

    for i, chunk in enumerate(chunks):
        rows.append({
            "idx": i,
            "chars": len(chunk),
            "lines": len(chunk.splitlines()),
            "first_line": chunk.splitlines()[0] if chunk else "",
            "preview": chunk[:300]
        })

    df = pd.DataFrame(rows)

    print("=" * 100)
    print(f"{name} - total chunks: {len(chunks)}")
    print("=" * 100)

    display(df[["idx", "chars", "lines", "first_line"]])

    return df


metadata_df = inspect_chunks(metadata_chunks, "metadata_chunks")
# Out:
# ====================================================================================================
# metadata_chunks - total chunks: 13
# ====================================================================================================
#     idx  chars  lines                                     first_line
# 0     0    397     11  # Metadata Schema hethong_phantich_chungkhoan
# 1     1    571     14                       ## 2) Bảng history_price
# 2     2    506     14                        ## 3) Bảng market_index
# 3     3    476     12                               ## 4) Bảng owner
# 4     4    727     17                    ## 5) Bảng company_overview
# 5     5   1066     22                                ## 6) Bảng bctc
# 6     6   1741     36                     ## 7) Bảng realtime_quotes
# 7     7    446     13                       ## 8) Bảng macro_economy
# 8     8   2540     47                     ## 9) Bảng financial_ratio
# 9     9   1272     30                     ## 10) Bảng electric_board
# 10   10    426     12                              ## 11) Bảng event
# 11   11    443     13                               ## 12) Bảng news
# 12   12   1774     29                    ## 13) Bảng vn_macro_yearly

# %% [markdown]
# chunking bctc.md

# %%
import re
import json
import ast

def extract_list_of_dicts(text):
    # Lấy nội dung trong code block nếu có
    match = re.search(r"```(?:json|python)?\s*(.*?)\s*```", text, re.DOTALL)
    raw = match.group(1).strip() if match else text.strip()

    # Tìm vị trí bắt đầu list
    start = raw.find("[")
    if start == -1:
        raise ValueError("Không tìm thấy dấu '[' bắt đầu list trong bctc_description.md")

    raw = raw[start:].strip()

    # Cách 1: parse JSON list đầu tiên, bỏ qua phần thừa phía sau
    try:
        decoder = json.JSONDecoder()
        data, end_idx = decoder.raw_decode(raw)
    except json.JSONDecodeError:
        # Cách 2: fallback cho Python literal list-of-dict
        try:
            data = ast.literal_eval(raw)
        except (SyntaxError, ValueError) as e:
            raise ValueError(
                "Không parse được bctc_description.md thành list-of-dict. "
                "File có thể có syntax lỗi hoặc phần text thừa nằm trong list."
            ) from e

    if not isinstance(data, list):
        raise ValueError("bctc_description.md phải là list: [{}, {}, ...]")

    if not all(isinstance(item, dict) for item in data):
        bad_idx = next(i for i, item in enumerate(data) if not isinstance(item, dict))
        raise ValueError(f"Phần tử index {bad_idx} không phải dict")

    return data


bctc_data = extract_list_of_dicts(bctc_raw_text)

print(f"Loaded {len(bctc_data)} BCTC objects")
# Out:
# Loaded 1720 BCTC objects

# %%
def chunk_bctc_by_objects(data, chunk_size=1):
    if not isinstance(data, list):
        raise TypeError("data phải là list các object từ bctc_description.md")

    chunks = []

    for i in range(0, len(data), chunk_size):
        sub = data[i:i + chunk_size]

        # Mỗi chunk là JSON array gồm tối đa `chunk_size` object
        chunk_text = json.dumps(sub, ensure_ascii=False, indent=2)
        chunks.append(chunk_text)

    return chunks


bctc_chunks = chunk_bctc_by_objects(bctc_data, BCTC_CHUNK_SIZE)
print(f"Created {len(bctc_chunks)} BCTC chunks, {BCTC_CHUNK_SIZE} objects/chunk")
# Out:
# Created 1720 BCTC chunks, 1 objects/chunk

# %%
bctc_df = inspect_chunks(bctc_chunks, "bctc_chunks")
# Out:
# ====================================================================================================
# bctc_chunks - total chunks: 1720
# ====================================================================================================
#        idx  chars  lines first_line
# 0        0    152      7          [
# 1        1    150      7          [
# 2        2    173      7          [
# 3        3    176      7          [
# 4        4    173      7          [
# ...    ...    ...    ...        ...
# 1715  1715    141      7          [
# 1716  1716    191      7          [
# 1717  1717    156      7          [
# 1718  1718    191      7          [
# 1719  1719    176      7          [
#
# [1720 rows x 4 columns]

# %%
records = []

# metadata
for i, chunk in enumerate(metadata_chunks):
    records.append({
        "doc_type": "metadata",
        "chunk_id": f"meta_{i}",
        "content": chunk
    })

# bctc
for i, chunk in enumerate(bctc_chunks):
    records.append({
        "doc_type": "bctc",
        "chunk_id": f"bctc_{i}",
        "content": chunk
    })

df = pd.DataFrame(records)

display(df.head())
# Out:
#    doc_type chunk_id                                            content
# 0  metadata   meta_0  # Metadata Schema hethong_phantich_chungkhoan\...
# 1  metadata   meta_1  ## 2) Bảng history_price\n\nMục đích: Lưu dữ l...
# 2  metadata   meta_2  ## 3) Bảng market_index\n\nMục đích: Lưu dữ li...
# 3  metadata   meta_3  ## 4) Bảng owner\n\nMục đích: Lưu thông tin cơ...
# 4  metadata   meta_4  ## 5) Bảng company_overview\n\nMục đích: Lưu h...

# %%
def embed_batch(texts):
    res = requests.post(
        EMBED_URL,
        json={
            "model": EMBED_MODEL,
            "input": texts
        }
    )
    res.raise_for_status()
    return [x["embedding"] for x in res.json()["data"]]

# %%
embeddings = []

batch_size = 16

for i in range(0, len(df), batch_size):
    batch = df["content"].iloc[i:i+batch_size].tolist()
    emb = embed_batch(batch)
    embeddings.extend(emb)

df["embedding"] = embeddings

# %%
df["chars"] = df["content"].apply(len)

display(df.head(20))
# Out:
#     doc_type chunk_id                                            content  \
# 0   metadata   meta_0  # Metadata Schema hethong_phantich_chungkhoan\...
# 1   metadata   meta_1  ## 2) Bảng history_price\n\nMục đích: Lưu dữ l...
# 2   metadata   meta_2  ## 3) Bảng market_index\n\nMục đích: Lưu dữ li...
# 3   metadata   meta_3  ## 4) Bảng owner\n\nMục đích: Lưu thông tin cơ...
# 4   metadata   meta_4  ## 5) Bảng company_overview\n\nMục đích: Lưu h...
# 5   metadata   meta_5  ## 6) Bảng bctc\n\nMục đích: Lưu dữ liệu chỉ t...
# 6   metadata   meta_6  ## 7) Bảng realtime_quotes\n\nMục đích: Lưu dữ...
# 7   metadata   meta_7  ## 8) Bảng macro_economy\n\nMục đích: Dữ liệu ...
# 8   metadata   meta_8  ## 9) Bảng financial_ratio\n\nMục đích: Lưu cá...
# 9   metadata   meta_9  ## 10) Bảng electric_board\n\nMục đích: Dữ liệ...
# 10  metadata  meta_10  ## 11) Bảng event\n\nMục đích: Lưu sự kiện doa...
# 11  metadata  meta_11  ## 12) Bảng news\n\nMục đích: Lưu tin tức thị ...
# 12  metadata  meta_12  ## 13) Bảng vn_macro_yearly\n\nMục đích: Lưu t...
# 13      bctc   bctc_0  [\n  {\n    "raw_name": "Ảnh hưởng của chênh l...
# 14      bctc   bctc_1  [\n  {\n    "raw_name": "Ảnh hưởng của thay đổ...
# 15      bctc   bctc_2  [\n  {\n    "raw_name": "Available-for Sales S...
# 16      bctc   bctc_3  [\n  {\n    "raw_name": "Balances with the SBV...
# 17      bctc   bctc_4  [\n  {\n    "raw_name": "Budget sources and ot...
# 18      bctc   bctc_5  [\n  {\n    "raw_name": "_Các công cụ tài chín...
# 19      bctc   bctc_6  [\n  {\n    "raw_name": "Các công cụ tài chính...
#
#                                             embedding  chars
# 0   [0.003127356758341193, -0.052400536835193634, ...    397
# 1   [-0.03607796132564545, -0.06249737739562988, -...    571
# 2   [-0.012028663419187069, -0.05921833962202072, ...    506
# 3   [-0.003747309558093548, -0.03166395425796509, ...    476
# 4   [-0.007478898856788874, -0.03944361209869385, ...    727
# 5   [-0.010004968382418156, 0.0031001190654933453,...   1066
# 6   [-0.011670362204313278, 0.01373785175383091, -...   1741
# 7   [-0.014640865847468376, -0.04529883712530136, ...    446
# 8   [-0.004887457937002182, -0.017098626121878624,...   2540
# 9   [-0.009576814249157906, -0.028571855276823044,...   1272
# 10  [-0.0063445232808589935, -0.025984158739447594...    426
# 11  [-0.023891346529126167, -0.022982778027653694,...    443
# 12  [-0.04363530874252319, -0.01550409384071827, -...   1774
# 13  [-0.02106214500963688, -0.013836557045578957, ...    152
# 14  [-0.026287179440259933, 0.0008238022564910352,...    150
# 15  [-0.022752027958631516, -0.019346080720424652,...    173
# 16  [-0.004759006202220917, 0.005705951247364283, ...    176
# 17  [0.011310170404613018, 0.01669764332473278, -0...    173
# 18  [-0.05040363967418671, -0.006985722109675407, ...    219
# 19  [-0.047982458025217056, -0.0060571301728487015...    218

# %% [markdown]
# insert

# %%
import asyncpg
import asyncio
import json

# %%
DB_URL = "postgresql://admin:123456@localhost:5432/postgres"
# sửa lại đúng DATABASE_URL_SYNC của bạn

# %%
async def insert_chunks_to_db(df):
    conn = await asyncpg.connect(DB_URL)

    for _, row in df.iterrows():
        embedding_str = "[" + ",".join(map(str, row["embedding"])) + "]"

        payload = {
            "chars": int(row["chars"]) if "chars" in df.columns else len(row["content"]),
        }

        source_file = (
            "metadata.md" if row["doc_type"] == "metadata"
            else "bctc_description.md"
        )

        chunk_index = int(row["chunk_id"].split("_")[-1])

        await conn.execute(
            """
            INSERT INTO hethong_phantich_chungkhoan.chatbot_knowledge_base (
                doc_type,
                source_file,
                chunk_id,
                chunk_index,
                content,
                embedding,
                payload
            )
            VALUES ($1, $2, $3, $4, $5, $6::vector, $7::jsonb)
            ON CONFLICT (chunk_id)
            DO UPDATE SET
                doc_type = EXCLUDED.doc_type,
                source_file = EXCLUDED.source_file,
                chunk_index = EXCLUDED.chunk_index,
                content = EXCLUDED.content,
                embedding = EXCLUDED.embedding,
                payload = EXCLUDED.payload
            """,
            row["doc_type"],
            source_file,
            row["chunk_id"],
            chunk_index,
            row["content"],
            embedding_str,
            json.dumps(payload, ensure_ascii=False),
        )

    await conn.close()
    print(f"Inserted/updated {len(df)} chunks OK")

# %%
await insert_chunks_to_db(df)
# Out:
# Inserted/updated 1733 chunks OK
